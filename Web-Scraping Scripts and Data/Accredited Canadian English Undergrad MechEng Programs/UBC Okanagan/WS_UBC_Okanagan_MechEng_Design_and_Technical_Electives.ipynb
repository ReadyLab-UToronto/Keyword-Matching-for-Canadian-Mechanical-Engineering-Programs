# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as ureq
import time
import re

# %% [markdown]
# # 1. import list of technical elective courses

# %%
import pandas as pd
df = pd.read_excel(r'UBC Okanagan MechEng Design and Technical Electives Names.xlsx', header = None)
df
# Out:
#             0
# 0    ENGR 401
# 1    ENGR 406
# 2    ENGR 458
# 3    ENGR 475
# 4    ENGR 482
# 5    ENGR 484
# 6    ENGR 491
# 7   ENGR 450
# 8   ENGR 454
# 9   ENGR 469
# 10  ENGR 478
# 11  ENGR 479
# 12  ENGR 485
# 13  ENGR 492
# 14  ENGR 497
# 15   MANF 486
# 16   ENGR 402
# 17   ENGR 418
# 18   ENGR 480
# 19   ENGR 481
# 20   ENGR 486
# 21   ENGR 489
# 22   ENGR 490
# 23   MANF 450
# 24   MANF 460
# 25   ENGR 416
# 26   ENGR 417
# 27   ENGR 439
# 28   ENGR 494
# 29   MANF 455
# 30   MANF 475

# %%
course_codes = list(df[0])

# %%
course_codes = [code[:8] for code in course_codes]
course_codes
# Out:
# ['ENGR 401',
#  'ENGR 406',
#  'ENGR 458',
#  'ENGR 475',
#  'ENGR 482',
#  'ENGR 484',
#  'ENGR 491',
#  'ENGR 450',
#  'ENGR 454',
#  'ENGR 469',
#  'ENGR 478',
#  'ENGR 479',
#  'ENGR 485',
#  'ENGR 492',
#  'ENGR 497',
#  'MANF 486',
#  'ENGR 402',
#  'ENGR 418',
#  'ENGR 480',
#  'ENGR 481',
#  'ENGR 486',
#  'ENGR 489',
#  'ENGR 490',
#  'MANF 450',
#  'MANF 460',
#  'ENGR 416',
#  'ENGR 417',
#  'ENGR 439',
#  'ENGR 494',
#  'MANF 455',
#  'MANF 475']

# %% [markdown]
# # 2. Use the course codes to find and scrape corresponding course names and descriptions

# %%
subject_links = {
    "ENGR": "http://www.calendar.ubc.ca/okanagan/courses.cfm?go=code&institution=2&code=ENGR",
    "MANF": "http://www.calendar.ubc.ca/okanagan/courses.cfm?go=code&institution=2&code=MANF"
}

# %%
course_names = []
course_descs = []
counter = 0
prev_link = ""

for course_code in course_codes:
    
    if subject_links[course_code.split()[0]] != prev_link:
        uClient = ureq(subject_links[course_code.split()[0]])
        time.sleep(2)
        page_html = uClient.read()
        uClient.close()
        page_soup = soup(page_html, "html.parser")
        prev_link = subject_links[course_code.split()[0]]
        
    course_title_container = page_soup.find(text = re.compile("^" + course_code))
    if course_title_container is None:
        print("Cannot find ", course_code)
    else:
        course_names.append(course_title_container.findNext().text.strip())
        course_descs.append(course_title_container.findNext().findNext().text.strip())
    
        counter += 1
        print("scraped ", course_code)
    
print(counter)
# Out:
# scraped  ENGR 401
# scraped  ENGR 406
# scraped  ENGR 458
# scraped  ENGR 475
# scraped  ENGR 482
# scraped  ENGR 484
# scraped  ENGR 491
# scraped  ENGR 450
# scraped  ENGR 454
# scraped  ENGR 469
# scraped  ENGR 478
# scraped  ENGR 479
# scraped  ENGR 485
# scraped  ENGR 492
# scraped  ENGR 497
# scraped  MANF 486
# scraped  ENGR 402
# scraped  ENGR 418
# scraped  ENGR 480
# scraped  ENGR 481
# scraped  ENGR 486
# scraped  ENGR 489
# scraped  ENGR 490
# scraped  MANF 450
# scraped  MANF 460
# scraped  ENGR 416
# scraped  ENGR 417
# scraped  ENGR 439
# scraped  ENGR 494
# scraped  MANF 455
# scraped  MANF 475
# 31

# %% [markdown]
# # 3. Inspect collected data and write to CSV

# %%
course_names
# Out:
# ['Bioinstrumentation',
#  'Microelectromechanical Systems',
#  'Power Electronics',
#  'Materials Selection and Design',
#  'Biomedical Engineering I',
#  'Heat and Mass Transfer',
#  'Computational Fluid Dynamics',
#  'Clinical Engineering',
#  'Motor Drive Systems',
#  'Polymer Engineering',
#  'Alternative Energy Systems',
#  'Measurement Principles in Thermal-Fluids',
#  'Heating, Ventilating, and Air Conditioning',
#  'Finite Element Methods',
#  'Combustion Processes',
#  'Mechatronic Systems Laboratory',
#  'Biotechnology: Fundamentals and Applications',
#  'Applied Machine Learning for Engineers',
#  'Modern Control',
#  'Mechatronics',
#  'Robot Modelling and Control',
#  'Multicriteria Optimization and Design of Experiments',
#  'Fluid Machinery',
#  'Life Cycle Analysis and Sustainability',
#  'Supply Chain Tactics and Strategies',
#  'Advanced Manufacturing CAD/CAM/CAE',
#  'Pipeline Integrity Management',
#  'Manufacturing Processes II',
#  'Autonomous Vehicle Technology',
#  'Factory Planning',
#  'Welding and Joining: Processes and Metallurgy']

# %%
course_descs
# Out:
# ['Bioinstruments used for tracking vitals, diagnosis, and treatment of disease in the vascular, muscular, nervous, and respiratory systems. Introduction to the fundamentals of each body system, electrical safety, signal acquisition, biosensors, transducers, amplifiers, and analysis of human physiological measurements. Hands on experience with sensors, biomedical devices, and design through labs. [3-2*-0] Prerequisite: All of APSC 193, APSC 254.',
#  'Mechanisms, design, fabrication, and testing of microsensors, actuators, and MicroElectroMechanical systems (MEMS).  Credit will not be granted for both ENGR 406 and ENGR 506 [3-2*-0] Prerequisite: Fourth-year standing in the B.A.Sc. Program',
#  'Applications and roles of power electronics, power semiconductor devices, diode rectifiers, phase-controlled rectifiers, DC-DC converters, DC-AC converters, resonant converters. Examples drawn from residential and industrial applications. Credit will be granted for only one of ENGR 458 or ENGR 558. [3-2*-0] Prerequisite: ENGR 320.',
#  'Review of materials classifications, ASTM standard for ferrous materials and non-ferrous alloys. Material property charts. Materials selection and material indices. Introduction to various materials processing. Process selection and materials selection with multiple constraints and objectives, cost analysis. [3-0-1*] Prerequisite: All of APSC 259, ENGR 376.',
#  'Introduction to the microcirculation; gas exchange in organs, including diffusion, perfusion and ventilation; surface energy in biological systems; principles of hemodynamics including vascular resistance and flow regimes at different levels of organs, tissues and cells; principles of tissue mechanics; introduction to tissue engineering; introduction to medical devices design and development. [3-0-0] Prerequisite: Fourth-year standing',
#  'Heat exchanger design, heat transfer with phase change, radiation heat transfer, steady and transient mass diffusion, convective mass transfer, simultaneous heat and mass transfer. Credit will be granted for only one of ENGR 484 or ENGR 584. [3-0-0] Prerequisite: All of ENGR 310, ENGR 385.',
#  'Computational fluid dynamics theory and methods for the numerical simulation of heat and fluid flow. Governing equations, meshing strategies and mesh requirements, finite difference methods, finite volume methods, solution of algebraic systems of equations, compressible flows, turbulence modelling. [3-0-0] Prerequisite: ENGR 310.',
#  'The clinical environment, clinical tools (for screening, diagnostics, treatment, monitoring, and rehabilitation) and regulatory requirements. [3-2*-0] Prerequisite: APSC 193 and fourth-year BASc standing.',
#  'Three-phase AC/DC PWM inverter, converter modulation techniques, abc/qd reference frame theory, brushed DC machine drives, induction motor drives, permanent magnet AC machines, brushless dc motors and drive circuits. [3-2*-0] Prerequisite: ENGR 320.',
#  'Introduction to polymer science and technology, molecular structure of polymers, polymer synthesis, structure-property relationship in polymers, physical properties of polymers, reinforced polymers, polymer composites and nanocomposites, polymer characterization, polymer processing, and forming. [3-0-0] Prerequisite: All of APSC 259, APSC 260.',
#  'Description of alternative sources of energy, electric vehicles, thermosolar energy, generation of electricity by photovoltaic effect, wind power energy, hydropower, geothermal, nuclear power, power plants with fuel cells, aspects of hydrogen as fuels, fuel from biomass, energy storage parameters, integration of alternative sources of energy. [3-0-0] Prerequisite: All of ENGR 375, ENGR 385.',
#  'Instruments and methods of measuring fluid thermo-physical properties.  Pressure-based velocity measurements. Thermal anemometry. Particle-based techniques for velocity measurement. Sonic anemometry/thermometry. Measurement of flow pressure and density. Measurement techniques for temperature and heat flux. Fundamentals of data processing and analysis. [3-0-0] Prerequisite: All of ENGR 310, ENGR 385.',
#  'Properties of moist air, air conditioning systems, heat transmission in building systems, heating and cooling load, refrigeration, pumps and piping design, fans and building air distribution. [3-0-0] Prerequisite: All of APSC 253, APSC 258, ENGR 385.',
#  'Finite Element Discretization, Direct Stiffness Method, Numerical Solution of Large Deformations, Formulation of Finite Elements, Auxiliary Equations, Thermomechanical Analysis, Computer Implementation of the Finite Element Methods, Case Studies in Material Forming and Multi-Physics. Credit will be granted for only one of ENGR 492 or ENGR 582. [3-0-0] Prerequisite: Fourth-year B.A.Sc. standing.',
#  'Combustion thermochemistry, fundamentals of mass transfer, chemical kinetics and combustion related chemical mechanisms, analysis of coupled thermal and chemical systems, laminar and turbulent flames, premixed and non-premixed flames, and combustion instabilities (e.g., thermoacoustics). 3-0-0 Prerequisite: All of ENGR 310, ENGR 375.',
#  'Smart sensors and actuators, electro-pneumatic actuators, automated control systems, industrial communication, smart maintenance, object detection, industrial robotics, modelling and simulation of mechatronic systems. Hands-on training on mechatronic system trainers in a laboratory scale [1-4-0] Prerequisite: One of MANF 386, ENGR 481.',
#  'Basics of biotechnology, DNA and RNA technologies, nanobiotechnology, medical biotechnology, and ethics in biotechnology. [3-0-0] Prerequisite: Third-year standing',
#  'Fundamentals of machine learning, toolboxes in machine learning, supervised learning, unsupervised learning, applications of machine learning in various engineering disciplines. Credit will be granted for only one of ENGR 418 or ENGR 518. [3-0-0] Prerequisite: Fourth-year standing in the B.A.Sc. program.',
#  'State-space modelling and design. Review of linear and matrix algebra, highlights of classical control theory, state-space modelling, continuous and discrete state equations, stability, controllability and observability, design of feedback systems. Credit will be granted for only one of ENGR 480 or ENGR 580. [3-2*-0] Prerequisite: ENGR 315.',
#  'Operating principles, analysis, modelling, and performance specifications of sensors, actuators, and mechatronic systems. Sensor selection, actuator sizing, and integration. Programmable logic control (PLC) systems and control techniques pertaining to actuators. Control system implementation. Credit will be granted for only one of ENGR 481 or ENGR 581. [3-2*-0] Prerequisite: Either (a) all of ENGR 315, ENGR 320 or (b) all of MANF 386, ENGR 320.',
#  'Spatial description and homogeneous transformations, manipulator kinematics (forward and inverse), Jacobian, motion trajectories. Manipulator dynamics, Lagrange-Euler and Newton-Euler formulation. Linear and nonlinear control, force control. Industrial robotic system and programming. Credit will be granted for only one of ENGR 486 or ENGR 586. [3-0-0] Prerequisite: ENGR 315.',
#  'Multiple attribute decision making, multiple objective decision making/optimization, fuzzy optimization, design and analysis of physical and computer experiments, uncertainty modelling, sensitivity analysis, weighting methods, computational tools and applications in multi-disciplinary design. Credit will be granted for only one of ENGR 489 or ENGR 589. [3-2*-0] Prerequisite: Fourth-year B.A.Sc. standing.',
#  'Principles and performance characteristics of turbomachinery, centrifugal and axial flow fans, compressors, pumps and turbines, and applications of dimensional analysis and similitude. [3-0-0] Prerequisite: ENGR 310.',
#  'Practical and theoretical applications of life cycle thinking in engineering projects, products, and processes. Understand international standards and methods in life cycle assessment (LCA), life cycle costing (LCC). Interpret and provide critical feedback on LCA/LCC studies and analyze claims on sustainability. Credit will be granted for only one of MANF450 or ENGR 544. [3-0-0] Prerequisite: Fourth-year standing.',
#  'Key concepts and techniques to analyze, manage and improve supply chain processes for different industries and markets. Emphasis on assessment of supply chain performance to improve competitiveness. [3-0-0] Prerequisite: Fourth-year standing.',
#  'CNC machining, Rapid prototyping, G-code, Computer Aided: Design, Manufacturing and Engineering, parametric design and analysis for optimization. [3-2-0] Prerequisite: ENGR 377.',
#  'Pipeline regulation codes, pipeline integrity management, pipeline operations, materials and fabrication, examination techniques, corrosion protection, and geohazards evaluation. [3-0-0] Prerequisite: Fourth-year standing in a B.A.Sc. program',
#  'Materials fabrication, forming, and joining: casting, rolling, forging, extrusion, and welding. Powder metallurgy and manufacture of metal alloys, metal matrix composites, and ceramics. Effect of fabrication process on evolution of crystallographic texture, residual stress, mechanical and service properties of materials. Process selection and technology development. [3-0-0] Prerequisite: Either (a) ENGR 377 or (b) MANF 230.',
#  'Autonomous navigation: perception, localization and mapping, motion planning, and motion control; and applications to unmanned aerial vehicles (UAVs), automated vehicles and self-driving cars.  Credit will be granted for only one of ENGR 494 or ENGR 535. [3-1-0] Prerequisite: ENGR 480.',
#  'Planning of resources, layout and logistics for manufacturing plants; hands-on training on modular production and cyber-physical manufacturing systems in a laboratory scale, virtual manufacturing environments and factory automation. [2-2-0] Prerequisite: MANF 465.',
#  'Welding and joining of metals: fusion and solid-state welding processes, brazing, and soldering. Effect of process parameters on joint size and quality. Fusion, partially melted, and heat affected zones. Non-equilibrium solidification, grain structure, and defect formation. Non-destructive testing and evaluation methods for welded joints. [3-2*-0] Prerequisite: One of ENGR 377, MANF 230.']

# %%
import pandas as pd

df = pd.DataFrame({
    
    "Course Number": course_codes,
    "Course Name": course_names,
    "Course Description": course_descs    
    
})

df
# Out:
#    Course Number                                        Course Name  \
# 0       ENGR 401                                 Bioinstrumentation
# 1       ENGR 406                     Microelectromechanical Systems
# 2       ENGR 458                                  Power Electronics
# 3       ENGR 475                     Materials Selection and Design
# 4       ENGR 482                           Biomedical Engineering I
# 5       ENGR 484                             Heat and Mass Transfer
# 6       ENGR 491                       Computational Fluid Dynamics
# 7       ENGR 450                               Clinical Engineering
# 8       ENGR 454                                Motor Drive Systems
# 9       ENGR 469                                Polymer Engineering
# 10      ENGR 478                         Alternative Energy Systems
# 11      ENGR 479           Measurement Principles in Thermal-Fluids
# 12      ENGR 485         Heating, Ventilating, and Air Conditioning
# 13      ENGR 492                             Finite Element Methods
# 14      ENGR 497                               Combustion Processes
# 15      MANF 486                     Mechatronic Systems Laboratory
# 16      ENGR 402       Biotechnology: Fundamentals and Applications
# 17      ENGR 418             Applied Machine Learning for Engineers
# 18      ENGR 480                                     Modern Control
# 19      ENGR 481                                       Mechatronics
# 20      ENGR 486                        Robot Modelling and Control
# 21      ENGR 489  Multicriteria Optimization and Design of Exper...
# 22      ENGR 490                                    Fluid Machinery
# 23      MANF 450             Life Cycle Analysis and Sustainability
# 24      MANF 460                Supply Chain Tactics and Strategies
# 25      ENGR 416                 Advanced Manufacturing CAD/CAM/CAE
# 26      ENGR 417                      Pipeline Integrity Management
# 27      ENGR 439                         Manufacturing Processes II
# 28      ENGR 494                      Autonomous Vehicle Technology
# 29      MANF 455                                   Factory Planning
# 30      MANF 475      Welding and Joining: Processes and Metallurgy
#
#                                    Course Description
# 0   Bioinstruments used for tracking vitals, diagn...
# 1   Mechanisms, design, fabrication, and testing o...
# 2   Applications and roles of power electronics, p...
# 3   Review of materials classifications, ASTM stan...
# 4   Introduction to the microcirculation; gas exch...
# 5   Heat exchanger design, heat transfer with phas...
# 6   Computational fluid dynamics theory and method...
# 7   The clinical environment, clinical tools (for ...
# 8   Three-phase AC/DC PWM inverter, converter modu...
# 9   Introduction to polymer science and technology...
# 10  Description of alternative sources of energy, ...
# 11  Instruments and methods of measuring fluid the...
# 12  Properties of moist air, air conditioning syst...
# 13  Finite Element Discretization, Direct Stiffnes...
# 14  Combustion thermochemistry, fundamentals of ma...
# 15  Smart sensors and actuators, electro-pneumatic...
# 16  Basics of biotechnology, DNA and RNA technolog...
# 17  Fundamentals of machine learning, toolboxes in...
# 18  State-space modelling and design. Review of li...
# 19  Operating principles, analysis, modelling, and...
# 20  Spatial description and homogeneous transforma...
# 21  Multiple attribute decision making, multiple o...
# 22  Principles and performance characteristics of ...
# 23  Practical and theoretical applications of life...
# 24  Key concepts and techniques to analyze, manage...
# 25  CNC machining, Rapid prototyping, G-code, Comp...
# 26  Pipeline regulation codes, pipeline integrity ...
# 27  Materials fabrication, forming, and joining: c...
# 28  Autonomous navigation: perception, localizatio...
# 29  Planning of resources, layout and logistics fo...
# 30  Welding and joining of metals: fusion and soli...

# %%
df.to_csv("UBC_Okanagan_MechEng_Design_and_Technical_Electives_Courses.csv", index = False)
